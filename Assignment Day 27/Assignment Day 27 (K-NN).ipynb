# %% [markdown]
# # K-NN (K-Nearest Neighbor)

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import neighbors
from warnings import filterwarnings
filterwarnings('ignore')

# %%
dataset=pd.read_csv('train.csv')
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (889, 12)

# %%
# Preprocessing
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
# dropping Cabin as it contains more null values 
dataset.drop(columns=['Cabin'],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Dropping irrelevant columns
dataset.drop(columns=['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
 # Conversion of variables
le=preprocessing.LabelEncoder()
le.fit(dataset['Sex'])
dataset['Sex']=le.transform(dataset['Sex'])
le.fit(dataset['Embarked'])
dataset['Embarked']=le.transform(dataset['Embarked'])

# %%
dataset.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
# splitting the dataset
y=dataset['Pclass']
X=dataset.drop(['Pclass'],axis=1)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
X_train.head()
# Out:
#      Survived  Sex   Age  SibSp  Parch     Fare  Embarked
# 350         0    1  45.0      0      0  35.0000         2
# 124         1    1  12.0      1      0  11.2417         0
# 577         0    0  45.0      1      0  14.4583         0
# 422         0    0  28.0      1      1  14.4000         2
# 118         0    0   2.0      4      2  31.2750         2

# %%
X_train.shape
# Out:
# (622, 7)

# %%
X_test.head()
# Out:
#      Survived  Sex   Age  SibSp  Parch      Fare  Embarked
# 14          0    0  14.0      0      0    7.8542         2
# 158         0    1  45.0      8      2   69.5500         2
# 762         1    0  36.0      1      2  120.0000         2
# 740         0    1  36.0      1      0   78.8500         2
# 482         1    0  63.0      0      0    9.5875         2

# %%
X_test.shape
# Out:
# (267, 7)

# %%
# Applying K-NN using function for iterations
def KNN(k):
    knn=neighbors.KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train).score(X_test,y_test)
    ypred=knn.predict(X_test)
    print("\nConfusion matrix when k=",k,"is :\n",confusion_matrix(y_test,ypred))
    print("Accuracy score when k =",k,"is :",accuracy_score(y_test,ypred,normalize=True))


r=range(1,268)
for i in r:
    KNN(i)
# Out:
# Confusion matrix when k= 1 is :
#  [[ 62   6   2]
#  [  3  37   9]
#  [  1   8 139]]
# Accuracy score when k = 1 is : 0.8913857677902621
#
# Confusion matrix when k= 2 is :
#  [[ 67   2   1]
#  [  8  37   4]
#  [  4  17 127]]
# Accuracy score when k = 2 is : 0.8651685393258427
#
# Confusion matrix when k= 3 is :
#  [[ 63   5   2]
#  [  7  28  14]
#  [  3   5 140]]
# Accuracy score when k = 3 is : 0.8651685393258427
#
# Confusion matrix when k= 4 is :
#  [[ 61   7   2]
#  [  8  30  11]
#  [  4  15 129]]
# Accuracy score when k = 4 is : 0.8239700374531835
#
# Confusion matrix when k= 5 is :
#  [[ 58  10   2]
#  [  7  28  14]
#  [  3   9 136]]
# Accuracy score when k = 5 is : 0.8314606741573034
#
# Confusion matrix when k= 6 is :
#  [[ 64   5   1]
#  [  7  32  10]
#  [  3  15 130]]
# Accuracy score when k = 6 is : 0.846441947565543
#
# Confusion matrix when k= 7 is :
#  [[ 59  10   1]
#  [  7  28  14]
#  [  3   7 138]]
# Accuracy score when k = 7 is : 0.8426966292134831
#
# Confusion matrix when k= 8 is :
#  [[ 61   8   1]
#  [  7  34   8]
#  [  3  13 132]]
# Accuracy score when k = 8 is : 0.850187265917603
#
# Confusion matrix when k= 9 is :
#  [[ 60   8   2]
#  [  7  29  13]
#  [  3   8 137]]
# Accuracy score when k = 9 is : 0.846441947565543
#
# Confusion matrix when k= 10 is :
#  [[ 60   8   2]
#  [  7  31  11]
#  [  3  13 132]]
# Accuracy score when k = 10 is : 0.8352059925093633
#
# Confusion matrix when k= 11 is :
#  [[ 60   9   1]
#  [  8  27  14]
#  [  6  10 132]]
# Accuracy score when k = 11 is : 0.8202247191011236
#
# Confusion matrix when k= 12 is :
#  [[ 61   8   1]
#  [  8  28  13]
#  [  5  11 132]]
# Accuracy score when k = 12 is : 0.8277153558052435
#
# Confusion matrix when k= 13 is :
#  [[ 60   9   1]
#  [  7  28  14]
#  [  5  10 133]]
# Accuracy score when k = 13 is : 0.8277153558052435
#
# Confusion matrix when k= 14 is :
#  [[ 60   8   2]
#  [  8  27  14]
#  [  5  11 132]]
# Accuracy score when k = 14 is : 0.8202247191011236
#
# Confusion matrix when k= 15 is :
#  [[ 60   7   3]
#  [  7  27  15]
#  [  5  13 130]]
# Accuracy score when k = 15 is : 0.8127340823970037
#
# Confusion matrix when k= 16 is :
#  [[ 60   7   3]
#  [  7  28  14]
#  [  5  13 130]]
# Accuracy score when k = 16 is : 0.8164794007490637
#
# Confusion matrix when k= 17 is :
#  [[ 60   7   3]
#  [  7  27  15]
#  [  5  12 131]]
# Accuracy score when k = 17 is : 0.8164794007490637
#
# Confusion matrix when k= 18 is :
#  [[ 60   6   4]
#  [  7  27  15]
#  [  5  12 131]]
# Accuracy score when k = 18 is : 0.8164794007490637
#
# Confusion matrix when k= 19 is :
#  [[ 60   6   4]
#  [  7  28  14]
#  [  5  12 131]]
# Accuracy score when k = 19 is : 0.8202247191011236
#
# Confusion matrix when k= 20 is :
#  [[ 60   6   4]
#  [  7  29  13]
#  [  5  13 130]]
# Accuracy score when k = 20 is : 0.8202247191011236
#
# Confusion matrix when k= 21 is :
#  [[ 60   7   3]
#  [  7  27  15]
#  [  5  13 130]]
# Accuracy score when k = 21 is : 0.8127340823970037
#
# Confusion matrix when k= 22 is :
#  [[ 61   6   3]
#  [  7  27  15]
#  [  9  14 125]]
# Accuracy score when k = 22 is : 0.797752808988764
#
# Confusion matrix when k= 23 is :
#  [[ 61   6   3]
#  [  7  27  15]
#  [  8  14 126]]
# Accuracy score when k = 23 is : 0.8014981273408239
#
# Confusion matrix when k= 24 is :
#  [[ 62   5   3]
#  [  7  27  15]
#  [  9  16 123]]
# Accuracy score when k = 24 is : 0.7940074906367042
#
# Confusion matrix when k= 25 is :
#  [[ 62   6   2]
#  [  7  26  16]
#  [  9  14 125]]
# Accuracy score when k = 25 is : 0.797752808988764
#
# Confusion matrix when k= 26 is :
#  [[ 61   5   4]
#  [  7  25  17]
#  [  9  15 124]]
# Accuracy score when k = 26 is : 0.7865168539325843
#
# Confusion matrix when k= 27 is :
#  [[ 62   5   3]
#  [  7  26  16]
#  [  9  14 125]]
# Accuracy score when k = 27 is : 0.797752808988764
#
# Confusion matrix when k= 28 is :
#  [[ 62   5   3]
#  [  7  24  18]
#  [ 10  15 123]]
# Accuracy score when k = 28 is : 0.7827715355805244
#
# Confusion matrix when k= 29 is :
#  [[ 62   5   3]
#  [  7  24  18]
#  [ 10  16 122]]
# Accuracy score when k = 29 is : 0.7790262172284644
#
# Confusion matrix when k= 30 is :
#  [[ 62   5   3]
#  [  7  24  18]
#  [ 10  16 122]]
# Accuracy score when k = 30 is : 0.7790262172284644
#
# Confusion matrix when k= 31 is :
#  [[ 62   5   3]
#  [  7  24  18]
#  [  9  15 124]]
# Accuracy score when k = 31 is : 0.7865168539325843
#
# Confusion matrix when k= 32 is :
#  [[ 62   5   3]
#  [  7  23  19]
#  [  9  15 124]]
# Accuracy score when k = 32 is : 0.7827715355805244
#
# Confusion matrix when k= 33 is :
#  [[ 62   5   3]
#  [  7  23  19]
#  [  9  13 126]]
# Accuracy score when k = 33 is : 0.7902621722846442
#
# Confusion matrix when k= 34 is :
#  [[ 62   5   3]
#  [  7  24  18]
#  [ 10  14 124]]
# Accuracy score when k = 34 is : 0.7865168539325843
#
# Confusion matrix when k= 35 is :
#  [[ 62   5   3]
#  [  7  22  20]
#  [ 10  14 124]]
# Accuracy score when k = 35 is : 0.7790262172284644
#
# Confusion matrix when k= 36 is :
#  [[ 62   5   3]
#  [  7  23  19]
#  [ 10  14 124]]
# Accuracy score when k = 36 is : 0.7827715355805244
#
# Confusion matrix when k= 37 is :
#  [[ 62   5   3]
#  [  7  22  20]
#  [  9  13 126]]
# Accuracy score when k = 37 is : 0.7865168539325843
#
# Confusion matrix when k= 38 is :
#  [[ 62   5   3]
#  [  7  23  19]
#  [  9  13 126]]
# Accuracy score when k = 38 is : 0.7902621722846442
#
# Confusion matrix when k= 39 is :
#  [[ 61   5   4]
#  [  7  19  23]
#  [  9  12 127]]
# Accuracy score when k = 39 is : 0.7752808988764045
#
# Confusion matrix when k= 40 is :
#  [[ 62   5   3]
#  [  7  20  22]
#  [  7  12 129]]
# Accuracy score when k = 40 is : 0.7902621722846442
#
# Confusion matrix when k= 41 is :
#  [[ 61   5   4]
#  [  7  19  23]
#  [  7  12 129]]
# Accuracy score when k = 41 is : 0.7827715355805244
#
# Confusion matrix when k= 42 is :
#  [[ 61   5   4]
#  [  7  20  22]
#  [  7  12 129]]
# Accuracy score when k = 42 is : 0.7865168539325843
#
# Confusion matrix when k= 43 is :
#  [[ 61   6   3]
#  [  7  19  23]
#  [  7  12 129]]
# Accuracy score when k = 43 is : 0.7827715355805244
#
# Confusion matrix when k= 44 is :
#  [[ 61   7   2]
#  [  7  20  22]
#  [  7  12 129]]
# Accuracy score when k = 44 is : 0.7865168539325843
#
# Confusion matrix when k= 45 is :
#  [[ 61   7   2]
#  [  7  19  23]
#  [  7  12 129]]
# Accuracy score when k = 45 is : 0.7827715355805244
#
# Confusion matrix when k= 46 is :
#  [[ 61   7   2]
#  [  7  20  22]
#  [  7  12 129]]
# Accuracy score when k = 46 is : 0.7865168539325843
#
# Confusion matrix when k= 47 is :
#  [[ 61   6   3]
#  [  7  17  25]
#  [  7  12 129]]
# Accuracy score when k = 47 is : 0.7752808988764045
#
# Confusion matrix when k= 48 is :
#  [[ 61   6   3]
#  [  7  17  25]
#  [  7  12 129]]
# Accuracy score when k = 48 is : 0.7752808988764045
#
# Confusion matrix when k= 49 is :
#  [[ 62   6   2]
#  [  7  16  26]
#  [  7  12 129]]
# Accuracy score when k = 49 is : 0.7752808988764045
#
# Confusion matrix when k= 50 is :
#  [[ 61   7   2]
#  [  7  16  26]
#  [  7  12 129]]
# Accuracy score when k = 50 is : 0.7715355805243446
#
# Confusion matrix when k= 51 is :
#  [[ 61   6   3]
#  [  7  14  28]
#  [  5  12 131]]
# Accuracy score when k = 51 is : 0.7715355805243446
#
# Confusion matrix when k= 52 is :
#  [[ 61   7   2]
#  [  7  15  27]
#  [  7  11 130]]
# Accuracy score when k = 52 is : 0.7715355805243446
#
# Confusion matrix when k= 53 is :
#  [[ 61   6   3]
#  [  7  12  30]
#  [  5  11 132]]
# Accuracy score when k = 53 is : 0.7677902621722846
#
# Confusion matrix when k= 54 is :
#  [[ 61   6   3]
#  [  7  12  30]
#  [  5  11 132]]
# Accuracy score when k = 54 is : 0.7677902621722846
#
# Confusion matrix when k= 55 is :
#  [[ 61   6   3]
#  [  7  12  30]
#  [  5  10 133]]
# Accuracy score when k = 55 is : 0.7715355805243446
#
# Confusion matrix when k= 56 is :
#  [[ 62   5   3]
#  [  7  12  30]
#  [  5  10 133]]
# Accuracy score when k = 56 is : 0.7752808988764045
#
# Confusion matrix when k= 57 is :
#  [[ 62   5   3]
#  [  7  12  30]
#  [  5  10 133]]
# Accuracy score when k = 57 is : 0.7752808988764045
#
# Confusion matrix when k= 58 is :
#  [[ 60   5   5]
#  [  6  12  31]
#  [  5  10 133]]
# Accuracy score when k = 58 is : 0.7677902621722846
#
# Confusion matrix when k= 59 is :
#  [[ 60   5   5]
#  [  6  11  32]
#  [  5  11 132]]
# Accuracy score when k = 59 is : 0.7602996254681648
#
# Confusion matrix when k= 60 is :
#  [[ 60   5   5]
#  [  6  12  31]
#  [  5  11 132]]
# Accuracy score when k = 60 is : 0.7640449438202247
#
# Confusion matrix when k= 61 is :
#  [[ 60   5   5]
#  [  6  11  32]
#  [  5  11 132]]
# Accuracy score when k = 61 is : 0.7602996254681648
#
# Confusion matrix when k= 62 is :
#  [[ 60   5   5]
#  [  6  11  32]
#  [  5  11 132]]
# Accuracy score when k = 62 is : 0.7602996254681648
#
# Confusion matrix when k= 63 is :
#  [[ 58   5   7]
#  [  6  11  32]
#  [  5  10 133]]
# Accuracy score when k = 63 is : 0.7565543071161048
#
# Confusion matrix when k= 64 is :
#  [[ 58   6   6]
#  [  5  11  33]
#  [  5  10 133]]
# Accuracy score when k = 64 is : 0.7565543071161048
#
# Confusion matrix when k= 65 is :
#  [[ 58   6   6]
#  [  5  11  33]
#  [  5   9 134]]
# Accuracy score when k = 65 is : 0.7602996254681648
#
# Confusion matrix when k= 66 is :
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   9 134]]
# Accuracy score when k = 66 is : 0.7565543071161048
#
# Confusion matrix when k= 67 is :
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 67 is : 0.7602996254681648
#
# Confusion matrix when k= 68 is :
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 68 is : 0.7602996254681648
#
# Confusion matrix when k= 69 is :
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   6 137]]
# Accuracy score when k = 69 is : 0.7640449438202247
#
# Confusion matrix when k= 70 is :
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   7 136]]
# Accuracy score when k = 70 is : 0.7640449438202247
#
# Confusion matrix when k= 71 is :
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   7 136]]
# Accuracy score when k = 71 is : 0.7640449438202247
#
# Confusion matrix when k= 72 is :
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 72 is : 0.7565543071161048
#
# Confusion matrix when k= 73 is :
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   6 137]]
# Accuracy score when k = 73 is : 0.7640449438202247
#
# Confusion matrix when k= 74 is :
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   6 137]]
# Accuracy score when k = 74 is : 0.7677902621722846
#
# Confusion matrix when k= 75 is :
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   6 137]]
# Accuracy score when k = 75 is : 0.7640449438202247
#
# Confusion matrix when k= 76 is :
#  [[ 56   7   7]
#  [  5  11  33]
#  [  5   5 138]]
# Accuracy score when k = 76 is : 0.7677902621722846
#
# Confusion matrix when k= 77 is :
#  [[ 57   6   7]
#  [  5  11  33]
#  [  5   5 138]]
# Accuracy score when k = 77 is : 0.7715355805243446
#
# Confusion matrix when k= 78 is :
#  [[ 56   5   9]
#  [  5  11  33]
#  [  5   6 137]]
# Accuracy score when k = 78 is : 0.7640449438202247
#
# Confusion matrix when k= 79 is :
#  [[ 56   5   9]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 79 is : 0.7565543071161048
#
# Confusion matrix when k= 80 is :
#  [[ 55   6   9]
#  [  5  11  33]
#  [  5   7 136]]
# Accuracy score when k = 80 is : 0.7565543071161048
#
# Confusion matrix when k= 81 is :
#  [[ 56   5   9]
#  [  5  11  33]
#  [  5   7 136]]
# Accuracy score when k = 81 is : 0.7602996254681648
#
# Confusion matrix when k= 82 is :
#  [[ 57   4   9]
#  [  5  10  34]
#  [  5   7 136]]
# Accuracy score when k = 82 is : 0.7602996254681648
#
# Confusion matrix when k= 83 is :
#  [[ 55   5  10]
#  [  5  10  34]
#  [  5   7 136]]
# Accuracy score when k = 83 is : 0.7528089887640449
#
# Confusion matrix when k= 84 is :
#  [[ 55   5  10]
#  [  5  10  34]
#  [  5   7 136]]
# Accuracy score when k = 84 is : 0.7528089887640449
#
# Confusion matrix when k= 85 is :
#  [[ 55   6   9]
#  [  5  10  34]
#  [  5   8 135]]
# Accuracy score when k = 85 is : 0.7490636704119851
#
# Confusion matrix when k= 86 is :
#  [[ 55   6   9]
#  [  5  10  34]
#  [  5   8 135]]
# Accuracy score when k = 86 is : 0.7490636704119851
#
# Confusion matrix when k= 87 is :
#  [[ 55   6   9]
#  [  5  10  34]
#  [  5   8 135]]
# Accuracy score when k = 87 is : 0.7490636704119851
#
# Confusion matrix when k= 88 is :
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   8 135]]
# Accuracy score when k = 88 is : 0.7453183520599251
#
# Confusion matrix when k= 89 is :
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   7 136]]
# Accuracy score when k = 89 is : 0.7490636704119851
#
# Confusion matrix when k= 90 is :
#  [[ 54   5  11]
#  [  5  10  34]
#  [  5   5 138]]
# Accuracy score when k = 90 is : 0.7565543071161048
#
# Confusion matrix when k= 91 is :
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   5 138]]
# Accuracy score when k = 91 is : 0.7565543071161048
#
# Confusion matrix when k= 92 is :
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   5 138]]
# Accuracy score when k = 92 is : 0.7565543071161048
#
# Confusion matrix when k= 93 is :
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   6 137]]
# Accuracy score when k = 93 is : 0.7528089887640449
#
# Confusion matrix when k= 94 is :
#  [[ 54   5  11]
#  [  5  10  34]
#  [  5   6 137]]
# Accuracy score when k = 94 is : 0.7528089887640449
#
# Confusion matrix when k= 95 is :
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   6 137]]
# Accuracy score when k = 95 is : 0.7528089887640449
#
# Confusion matrix when k= 96 is :
#  [[ 55   4  11]
#  [  5  10  34]
#  [  5   6 137]]
# Accuracy score when k = 96 is : 0.7565543071161048
#
# Confusion matrix when k= 97 is :
#  [[ 53   6  11]
#  [  5  10  34]
#  [  5   7 136]]
# Accuracy score when k = 97 is : 0.7453183520599251
#
# Confusion matrix when k= 98 is :
#  [[ 54   6  10]
#  [  5  10  34]
#  [  5   5 138]]
# Accuracy score when k = 98 is : 0.7565543071161048
#
# Confusion matrix when k= 99 is :
#  [[ 53   6  11]
#  [  5  10  34]
#  [  5   9 134]]
# Accuracy score when k = 99 is : 0.7378277153558053
#
# Confusion matrix when k= 100 is :
#  [[ 53   6  11]
#  [  5  10  34]
#  [  5   9 134]]
# Accuracy score when k = 100 is : 0.7378277153558053
#
# Confusion matrix when k= 101 is :
#  [[ 53   6  11]
#  [  5  10  34]
#  [  5  11 132]]
# Accuracy score when k = 101 is : 0.7303370786516854
#
# Confusion matrix when k= 102 is :
#  [[ 53   5  12]
#  [  5  10  34]
#  [  5  11 132]]
# Accuracy score when k = 102 is : 0.7303370786516854
#
# Confusion matrix when k= 103 is :
#  [[ 53   7  10]
#  [  6  10  33]
#  [  5  10 133]]
# Accuracy score when k = 103 is : 0.7340823970037453
#
# Confusion matrix when k= 104 is :
#  [[ 53   7  10]
#  [  6  10  33]
#  [  5  10 133]]
# Accuracy score when k = 104 is : 0.7340823970037453
#
# Confusion matrix when k= 105 is :
#  [[ 53   7  10]
#  [  6  11  32]
#  [  5  10 133]]
# Accuracy score when k = 105 is : 0.7378277153558053
#
# Confusion matrix when k= 106 is :
#  [[ 53   6  11]
#  [  5  12  32]
#  [  5  10 133]]
# Accuracy score when k = 106 is : 0.7415730337078652
#
# Confusion matrix when k= 107 is :
#  [[ 53   9   8]
#  [  5  12  32]
#  [  5  10 133]]
# Accuracy score when k = 107 is : 0.7415730337078652
#
# Confusion matrix when k= 108 is :
#  [[ 53   8   9]
#  [  5  12  32]
#  [  5   9 134]]
# Accuracy score when k = 108 is : 0.7453183520599251
#
# Confusion matrix when k= 109 is :
#  [[ 53   9   8]
#  [  5  12  32]
#  [  5   8 135]]
# Accuracy score when k = 109 is : 0.7490636704119851
#
# Confusion matrix when k= 110 is :
#  [[ 53   8   9]
#  [  5  13  31]
#  [  5   8 135]]
# Accuracy score when k = 110 is : 0.7528089887640449
#
# Confusion matrix when k= 111 is :
#  [[ 53   8   9]
#  [  5  12  32]
#  [  5   8 135]]
# Accuracy score when k = 111 is : 0.7490636704119851
#
# Confusion matrix when k= 112 is :
#  [[ 53   8   9]
#  [  5  12  32]
#  [  5   9 134]]
# Accuracy score when k = 112 is : 0.7453183520599251
#
# Confusion matrix when k= 113 is :
#  [[ 53   8   9]
#  [  5  12  32]
#  [  5   8 135]]
# Accuracy score when k = 113 is : 0.7490636704119851
#
# Confusion matrix when k= 114 is :
#  [[ 53   9   8]
#  [  5  12  32]
#  [  5   8 135]]
# Accuracy score when k = 114 is : 0.7490636704119851
#
# Confusion matrix when k= 115 is :
#  [[ 53  11   6]
#  [  5  12  32]
#  [  5   8 135]]
# Accuracy score when k = 115 is : 0.7490636704119851
#
# Confusion matrix when k= 116 is :
#  [[ 53  11   6]
#  [  5  12  32]
#  [  5   8 135]]
# Accuracy score when k = 116 is : 0.7490636704119851
#
# Confusion matrix when k= 117 is :
#  [[ 53  11   6]
#  [  5  12  32]
#  [  5   7 136]]
# Accuracy score when k = 117 is : 0.7528089887640449
#
# Confusion matrix when k= 118 is :
#  [[ 53  11   6]
#  [  5  12  32]
#  [  5   8 135]]
# Accuracy score when k = 118 is : 0.7490636704119851
#
# Confusion matrix when k= 119 is :
#  [[ 53  12   5]
#  [  5  12  32]
#  [  5   8 135]]
# Accuracy score when k = 119 is : 0.7490636704119851
#
# Confusion matrix when k= 120 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 120 is : 0.7453183520599251
#
# Confusion matrix when k= 121 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 121 is : 0.7453183520599251
#
# Confusion matrix when k= 122 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 122 is : 0.7453183520599251
#
# Confusion matrix when k= 123 is :
#  [[ 53  12   5]
#  [  5  10  34]
#  [  5   8 135]]
# Accuracy score when k = 123 is : 0.7415730337078652
#
# Confusion matrix when k= 124 is :
#  [[ 53  13   4]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 124 is : 0.7453183520599251
#
# Confusion matrix when k= 125 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   8 135]]
# Accuracy score when k = 125 is : 0.7453183520599251
#
# Confusion matrix when k= 126 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   7 136]]
# Accuracy score when k = 126 is : 0.7490636704119851
#
# Confusion matrix when k= 127 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   7 136]]
# Accuracy score when k = 127 is : 0.7490636704119851
#
# Confusion matrix when k= 128 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   6 137]]
# Accuracy score when k = 128 is : 0.7528089887640449
#
# Confusion matrix when k= 129 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   6 137]]
# Accuracy score when k = 129 is : 0.7528089887640449
#
# Confusion matrix when k= 130 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 130 is : 0.7602996254681648
#
# Confusion matrix when k= 131 is :
#  [[ 53  12   5]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 131 is : 0.7602996254681648
#
# Confusion matrix when k= 132 is :
#  [[ 53  13   4]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 132 is : 0.7602996254681648
#
# Confusion matrix when k= 133 is :
#  [[ 53  13   4]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 133 is : 0.7602996254681648
# Confusion matrix when k= 134 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 134 is : 0.7565543071161048
#
# Confusion matrix when k= 135 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# Accuracy score when k = 135 is : 0.7602996254681648
#
# Confusion matrix when k= 136 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# Accuracy score when k = 136 is : 0.7602996254681648
#
# Confusion matrix when k= 137 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# Accuracy score when k = 137 is : 0.7602996254681648
#
# Confusion matrix when k= 138 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# Accuracy score when k = 138 is : 0.7602996254681648
#
# Confusion matrix when k= 139 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# Accuracy score when k = 139 is : 0.7602996254681648
#
# Confusion matrix when k= 140 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# Accuracy score when k = 140 is : 0.7602996254681648
#
# Confusion matrix when k= 141 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   3 140]]
# Accuracy score when k = 141 is : 0.7602996254681648
#
# Confusion matrix when k= 142 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 142 is : 0.7565543071161048
#
# Confusion matrix when k= 143 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 143 is : 0.7565543071161048
#
# Confusion matrix when k= 144 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 144 is : 0.7565543071161048
#
# Confusion matrix when k= 145 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 145 is : 0.7565543071161048
#
# Confusion matrix when k= 146 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   4 139]]
# Accuracy score when k = 146 is : 0.7565543071161048
#
# Confusion matrix when k= 147 is :
#  [[ 52  13   5]
#  [  5  11  33]
#  [  5   2 141]]
# Accuracy score when k = 147 is : 0.7640449438202247
#
# Confusion matrix when k= 148 is :
#  [[ 52  11   7]
#  [  5  11  33]
#  [  5   1 142]]
# Accuracy score when k = 148 is : 0.7677902621722846
#
# Confusion matrix when k= 149 is :
#  [[ 52  11   7]
#  [  5  11  33]
#  [  5   1 142]]
# Accuracy score when k = 149 is : 0.7677902621722846
#
# Confusion matrix when k= 150 is :
#  [[ 52  11   7]
#  [  5  11  33]
#  [  5   1 142]]
# Accuracy score when k = 150 is : 0.7677902621722846
#
# Confusion matrix when k= 151 is :
#  [[ 52  11   7]
#  [  5  11  33]
#  [  5   1 142]]
# Accuracy score when k = 151 is : 0.7677902621722846
#
# Confusion matrix when k= 152 is :
#  [[ 52  11   7]
#  [  5  10  34]
#  [  5   1 142]]
# Accuracy score when k = 152 is : 0.7640449438202247
#
# Confusion matrix when k= 153 is :
#  [[ 52   9   9]
#  [  5  10  34]
#  [  5   1 142]]
# Accuracy score when k = 153 is : 0.7640449438202247
#
# Confusion matrix when k= 154 is :
#  [[ 52   9   9]
#  [  5  10  34]
#  [  5   1 142]]
# Accuracy score when k = 154 is : 0.7640449438202247
#
# Confusion matrix when k= 155 is :
#  [[ 52   9   9]
#  [  5  10  34]
#  [  5   1 142]]
# Accuracy score when k = 155 is : 0.7640449438202247
#
# Confusion matrix when k= 156 is :
#  [[ 52   9   9]
#  [  5   9  35]
#  [  5   1 142]]
# Accuracy score when k = 156 is : 0.7602996254681648
#
# Confusion matrix when k= 157 is :
#  [[ 52   9   9]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 157 is : 0.7565543071161048
#
# Confusion matrix when k= 158 is :
#  [[ 52   9   9]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 158 is : 0.7565543071161048
#
# Confusion matrix when k= 159 is :
#  [[ 52   9   9]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 159 is : 0.7565543071161048
#
# Confusion matrix when k= 160 is :
#  [[ 52   9   9]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 160 is : 0.7565543071161048
#
# Confusion matrix when k= 161 is :
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 161 is : 0.7528089887640449
#
# Confusion matrix when k= 162 is :
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 162 is : 0.7528089887640449
#
# Confusion matrix when k= 163 is :
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 163 is : 0.7528089887640449
#
# Confusion matrix when k= 164 is :
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 164 is : 0.7528089887640449
#
# Confusion matrix when k= 165 is :
#  [[ 52   9   9]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 165 is : 0.7528089887640449
#
# Confusion matrix when k= 166 is :
#  [[ 52   8  10]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 166 is : 0.7528089887640449
#
# Confusion matrix when k= 167 is :
#  [[ 52   7  11]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 167 is : 0.7528089887640449
#
# Confusion matrix when k= 168 is :
#  [[ 52   7  11]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 168 is : 0.7528089887640449
#
# Confusion matrix when k= 169 is :
#  [[ 52   6  12]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 169 is : 0.7528089887640449
#
# Confusion matrix when k= 170 is :
#  [[ 52   6  12]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 170 is : 0.7528089887640449
#
# Confusion matrix when k= 171 is :
#  [[ 52   6  12]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 171 is : 0.7528089887640449
#
# Confusion matrix when k= 172 is :
#  [[ 52   6  12]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 172 is : 0.7528089887640449
#
# Confusion matrix when k= 173 is :
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 173 is : 0.7565543071161048
#
# Confusion matrix when k= 174 is :
#  [[ 50   8  12]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 174 is : 0.7490636704119851
#
# Confusion matrix when k= 175 is :
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 175 is : 0.7565543071161048
#
# Confusion matrix when k= 176 is :
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 176 is : 0.7565543071161048
#
# Confusion matrix when k= 177 is :
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 177 is : 0.7565543071161048
#
# Confusion matrix when k= 178 is :
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 178 is : 0.7565543071161048
#
# Confusion matrix when k= 179 is :
#  [[ 52   6  12]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 179 is : 0.7565543071161048
#
# Confusion matrix when k= 180 is :
#  [[ 50   7  13]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 180 is : 0.7490636704119851
#
# Confusion matrix when k= 181 is :
#  [[ 52   5  13]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 181 is : 0.7565543071161048
#
# Confusion matrix when k= 182 is :
#  [[ 52   5  13]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 182 is : 0.7565543071161048
#
# Confusion matrix when k= 183 is :
#  [[ 52   5  13]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 183 is : 0.7565543071161048
#
# Confusion matrix when k= 184 is :
#  [[ 51   5  14]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 184 is : 0.7528089887640449
#
# Confusion matrix when k= 185 is :
#  [[ 51   5  14]
#  [  5   7  37]
#  [  5   0 143]]
# Accuracy score when k = 185 is : 0.7528089887640449
#
# Confusion matrix when k= 186 is :
#  [[ 51   5  14]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 186 is : 0.7490636704119851
#
# Confusion matrix when k= 187 is :
#  [[ 51   5  14]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 187 is : 0.7490636704119851
#
# Confusion matrix when k= 188 is :
#  [[ 51   5  14]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 188 is : 0.7490636704119851
#
# Confusion matrix when k= 189 is :
#  [[ 50   5  15]
#  [  5   6  38]
#  [  5   0 143]]
# Accuracy score when k = 189 is : 0.7453183520599251
#
# Confusion matrix when k= 190 is :
#  [[ 50   5  15]
#  [  5   5  39]
#  [  5   0 143]]
# Accuracy score when k = 190 is : 0.7415730337078652
#
# Confusion matrix when k= 191 is :
#  [[ 50   5  15]
#  [  5   5  39]
#  [  5   0 143]]
# Accuracy score when k = 191 is : 0.7415730337078652
#
# Confusion matrix when k= 192 is :
#  [[ 50   5  15]
#  [  5   5  39]
#  [  5   0 143]]
# Accuracy score when k = 192 is : 0.7415730337078652
#
# Confusion matrix when k= 193 is :
#  [[ 50   5  15]
#  [  5   5  39]
#  [  5   0 143]]
# Accuracy score when k = 193 is : 0.7415730337078652
#
# Confusion matrix when k= 194 is :
#  [[ 48   7  15]
#  [  5   4  40]
#  [  5   0 143]]
# Accuracy score when k = 194 is : 0.7303370786516854
#
# Confusion matrix when k= 195 is :
#  [[ 48   7  15]
#  [  5   2  42]
#  [  5   0 143]]
# Accuracy score when k = 195 is : 0.7228464419475655
#
# Confusion matrix when k= 196 is :
#  [[ 48   7  15]
#  [  5   2  42]
#  [  5   0 143]]
# Accuracy score when k = 196 is : 0.7228464419475655
#
# Confusion matrix when k= 197 is :
#  [[ 48   7  15]
#  [  5   2  42]
#  [  5   0 143]]
# Accuracy score when k = 197 is : 0.7228464419475655
#
# Confusion matrix when k= 198 is :
#  [[ 48   7  15]
#  [  5   2  42]
#  [  5   0 143]]
# Accuracy score when k = 198 is : 0.7228464419475655
#
# Confusion matrix when k= 199 is :
#  [[ 48   7  15]
#  [  5   1  43]
#  [  5   0 143]]
# Accuracy score when k = 199 is : 0.7191011235955056
#
# Confusion matrix when k= 200 is :
#  [[ 48   6  16]
#  [  5   1  43]
#  [  5   0 143]]
# Accuracy score when k = 200 is : 0.7191011235955056
#
# Confusion matrix when k= 201 is :
#  [[ 48   6  16]
#  [  5   2  42]
#  [  5   0 143]]
# Accuracy score when k = 201 is : 0.7228464419475655
#
# Confusion matrix when k= 202 is :
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 202 is : 0.7228464419475655
#
# Confusion matrix when k= 203 is :
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 203 is : 0.7228464419475655
#
# Confusion matrix when k= 204 is :
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 204 is : 0.7228464419475655
#
# Confusion matrix when k= 205 is :
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 205 is : 0.7228464419475655
#
# Confusion matrix when k= 206 is :
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 206 is : 0.7228464419475655
#
# Confusion matrix when k= 207 is :
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 207 is : 0.7228464419475655
#
# Confusion matrix when k= 208 is :
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 208 is : 0.7228464419475655
#
# Confusion matrix when k= 209 is :
#  [[ 48   6  16]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 209 is : 0.7228464419475655
#
# Confusion matrix when k= 210 is :
#  [[ 48   5  17]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 210 is : 0.7228464419475655
#
# Confusion matrix when k= 211 is :
#  [[ 48   5  17]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 211 is : 0.7228464419475655
#
# Confusion matrix when k= 212 is :
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 212 is : 0.7228464419475655
#
# Confusion matrix when k= 213 is :
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 213 is : 0.7228464419475655
#
# Confusion matrix when k= 214 is :
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 214 is : 0.7228464419475655
#
# Confusion matrix when k= 215 is :
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 215 is : 0.7228464419475655
#
# Confusion matrix when k= 216 is :
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 216 is : 0.7228464419475655
#
# Confusion matrix when k= 217 is :
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 217 is : 0.7228464419475655
#
# Confusion matrix when k= 218 is :
#  [[ 48   4  18]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 218 is : 0.7228464419475655
#
# Confusion matrix when k= 219 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 219 is : 0.7228464419475655
#
# Confusion matrix when k= 220 is :
#  [[ 48   3  19]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 220 is : 0.7228464419475655
#
# Confusion matrix when k= 221 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 221 is : 0.7228464419475655
#
# Confusion matrix when k= 222 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 222 is : 0.7228464419475655
#
# Confusion matrix when k= 223 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 223 is : 0.7228464419475655
#
# Confusion matrix when k= 224 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 224 is : 0.7228464419475655
#
# Confusion matrix when k= 225 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 225 is : 0.7228464419475655
#
# Confusion matrix when k= 226 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 226 is : 0.7228464419475655
#
# Confusion matrix when k= 227 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 227 is : 0.7228464419475655
#
# Confusion matrix when k= 228 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 228 is : 0.7228464419475655
#
# Confusion matrix when k= 229 is :
#  [[ 48   2  20]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 229 is : 0.7228464419475655
#
# Confusion matrix when k= 230 is :
#  [[ 48   1  21]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 230 is : 0.7228464419475655
#
# Confusion matrix when k= 231 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 231 is : 0.7228464419475655
#
# Confusion matrix when k= 232 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 232 is : 0.7228464419475655
#
# Confusion matrix when k= 233 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 233 is : 0.7228464419475655
#
# Confusion matrix when k= 234 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 234 is : 0.7228464419475655
#
# Confusion matrix when k= 235 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 235 is : 0.7228464419475655
#
# Confusion matrix when k= 236 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 236 is : 0.7228464419475655
#
# Confusion matrix when k= 237 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 237 is : 0.7228464419475655
#
# Confusion matrix when k= 238 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 238 is : 0.7228464419475655
#
# Confusion matrix when k= 239 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 239 is : 0.7228464419475655
#
# Confusion matrix when k= 240 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 240 is : 0.7228464419475655
#
# Confusion matrix when k= 241 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 241 is : 0.7228464419475655
#
# Confusion matrix when k= 242 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 242 is : 0.7228464419475655
#
# Confusion matrix when k= 243 is :
#  [[ 48   0  22]
#  [  4   2  43]
#  [  5   0 143]]
# Accuracy score when k = 243 is : 0.7228464419475655
#
# Confusion matrix when k= 244 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 244 is : 0.7191011235955056
#
# Confusion matrix when k= 245 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 245 is : 0.7191011235955056
#
# Confusion matrix when k= 246 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 246 is : 0.7191011235955056
#
# Confusion matrix when k= 247 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 247 is : 0.7191011235955056
#
# Confusion matrix when k= 248 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 248 is : 0.7191011235955056
#
# Confusion matrix when k= 249 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 249 is : 0.7191011235955056
#
# Confusion matrix when k= 250 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 250 is : 0.7191011235955056
#
# Confusion matrix when k= 251 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 251 is : 0.7191011235955056
#
# Confusion matrix when k= 252 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 252 is : 0.7191011235955056
#
# Confusion matrix when k= 253 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 253 is : 0.7191011235955056
#
# Confusion matrix when k= 254 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 254 is : 0.7191011235955056
#
# Confusion matrix when k= 255 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 255 is : 0.7191011235955056
#
# Confusion matrix when k= 256 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 256 is : 0.7191011235955056
#
# Confusion matrix when k= 257 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 257 is : 0.7191011235955056
#
# Confusion matrix when k= 258 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 258 is : 0.7191011235955056
#
# Confusion matrix when k= 259 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 259 is : 0.7191011235955056
#
# Confusion matrix when k= 260 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 260 is : 0.7191011235955056
#
# Confusion matrix when k= 261 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 261 is : 0.7191011235955056
#
# Confusion matrix when k= 262 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 262 is : 0.7191011235955056
#
# Confusion matrix when k= 263 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 263 is : 0.7191011235955056
# Confusion matrix when k= 264 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 264 is : 0.7191011235955056
#
# Confusion matrix when k= 265 is :
#  [[ 48   0  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 265 is : 0.7191011235955056
#
# Confusion matrix when k= 266 is :
#  [[ 47   0  23]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 266 is : 0.7153558052434457
#
# Confusion matrix when k= 267 is :
#  [[ 47   1  22]
#  [  4   1  44]
#  [  5   0 143]]
# Accuracy score when k = 267 is : 0.7153558052434457

# %% [markdown]
# # Inference
# The Accuracy is highest when k=1 which is 0.8913 and the accuracy decreases as the k value increases.
#
# The accuracy is lowest when k=267 which is 0.7153.
#
# Hence, we use k=1 value for the most accurate prediction.
